# %% [markdown]
# <a href="https://colab.research.google.com/github/chowyiyin/CharacterLevelLanguageModel/blob/master/Enron_Dataset_Cleanup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook helps to remove duplicates in a dataset (consisting of directories of text files)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !cp '/content/gdrive/My Drive/maildir.zip' 'maildir.zip'
# !ls -al
# Out:
# total 915496
# drwxr-xr-x 1 root root      4096 Jun 24 03:44 .
# drwxr-xr-x 1 root root      4096 Jun 24 03:42 ..
# drwxr-xr-x 1 root root      4096 Jun 19 16:15 .config
# drwx------ 4 root root      4096 Jun 24 03:44 gdrive
# -rw------- 1 root root 937441588 Jun 24 03:44 maildir.zip
# drwxr-xr-x 1 root root      4096 Jun 17 16:18 sample_data

# %%
# !unzip maildir.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: __MACOSX/maildir/germany-c/bankrupt/transport/ena_upstream/._2.
#   inflating: maildir/germany-c/bankrupt/transport/sonat/3.
#   inflating: __MACOSX/maildir/germany-c/bankrupt/transport/sonat/._3.
#   inflating: maildir/germany-c/bankrupt/transport/sonat/9.
#   inflating: __MACOSX/maildir/germany-c/bankrupt/transport/sonat/._9.
#   inflating: maildir/germany-c/bankrupt/transport/sonat/13.
#   inflating: __MACOSX/maildir/germany-c/bankrupt/transport/sonat/._13.
#   inflating: maildir/germany-c/bankrupt/transport/sonat/10.
#   inflating: __MACOSX/maildir/germany-c/bankrupt/transport/sonat/._10.
#   inflating: maildir/germany-c/bankrupt/transport/sonat/4.
#   inflating: __MACOSX/maildir/germany-c/bankrupt/transport/sonat/._4.
#   inflating: maildir/germany-c/bankrupt/transport/sonat/14.
#   inflating: __MACOSX/maildir/germany-c/bankrupt/transport/sonat/._14.
#   inflating: maildir/germany-c/bankrupt/transport/sonat/7.
# ...

# %%
existing_files = set()

# %%
def removeDuplicates(directory):
  to_remove = []
  for root, directories, filenames in os.walk(directory):
    for directory in directories:
      to_remove.extend(removeDuplicates(directory))
    for filename in filenames:
      try:
        path = os.path.join(root, filename)
        text = open(path, encoding='utf-8').read().strip()
        if text in existing_files:
          to_remove.append(path)
        else:
          existing_files.add(text)
      except:
        continue
  return to_remove

# %%
import os
to_remove = removeDuplicates('maildir')
print(len(to_remove))
for file in to_remove:
  # !rm $file

  print(file)
# !zip -r maildir-clean.zip maildir
existing_text = set() # clean up
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: maildir/symes-k/all_documents/2258. (deflated 37%)
#   adding: maildir/symes-k/all_documents/1904. (deflated 34%)
#   adding: maildir/symes-k/all_documents/1720. (deflated 50%)
#   adding: maildir/symes-k/all_documents/1562. (deflated 47%)
#   adding: maildir/symes-k/all_documents/537. (deflated 50%)
#   adding: maildir/symes-k/all_documents/3253. (deflated 45%)
#   adding: maildir/symes-k/all_documents/1214. (deflated 40%)
#   adding: maildir/symes-k/all_documents/3188. (deflated 30%)
#   adding: maildir/symes-k/all_documents/2411. (deflated 40%)
#   adding: maildir/symes-k/all_documents/1480. (deflated 59%)
#   adding: maildir/symes-k/all_documents/1868. (deflated 43%)
#   adding: maildir/symes-k/all_documents/1171. (deflated 30%)
#   adding: maildir/symes-k/all_documents/1032. (deflated 34%)
#   adding: maildir/symes-k/all_documents/3429. (deflated 36%)
#   adding: maildir/symes-k/all_documents/2523. (deflated 35%)
# ...

# %%
# !cp 'maildir-clean.zip' '/content/gdrive/My Drive/maildir-clean.zip'
